# %%
from vtkplotter import *

embedWindow('2d')
# settings.useFXAA = True
# settings.multiSamples=8

symbols = ['.', 'p','*','h','D','d','o','v','^','>','<','s','x','+','a']

for i,s in enumerate(symbols):
    Marker(s, filled=True).x(i*0.6).color(i)
    Text(s, pos=[i*0.6,-0.6,0], s=0.12, depth=0).color('k')

show(..., bg='w', size=(900,400), zoom=2)
# Out:
# <PIL.Image.Image image mode=RGB size=2700x1200 at 0x7F15CB1ABBD0>
