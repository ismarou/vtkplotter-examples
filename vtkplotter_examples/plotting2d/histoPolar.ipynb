# %%
from vtkplotter import *
import numpy as np

embedWindow('2d')
# settings.useFXAA = True
# settings.multiSamples=8

##################################################################
radhisto = polarHistogram(np.random.rand(200)*6.28,
                           title="random orientations",
                           bins=10,
                           #c='orange', #uniform color
                           labels=["label"+str(i) for i in range(10)],
                          )

show(radhisto, axes=0, bg="w")
screenshot(scale=2)
# Out:
# <PIL.Image.Image image mode=RGB size=2700x2100 at 0x7F7C8FB1BF50>
