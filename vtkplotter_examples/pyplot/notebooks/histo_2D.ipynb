# %%
"""Histogram 2D"""

from vtkplotter import *
import numpy as np

embedWindow('2d')
n = 10000
x = np.random.normal(2, 1, n)*1.2
y = np.random.normal(1, 1, n)

h = histogram(x, y, bins=(25,25), cmap='cividis')

show(h, axes=1, viewup='2d')
# Out:
# <PIL.Image.Image image mode=RGB size=2700x2100 at 0x7F1BB87B1050>
